# %% [markdown]
# ![QCFRIicon.png](data:image/png;base64,...)

# %% [markdown]
# # Oracle Building
# ## Lesson 7

# %% [markdown]
# ### Installations and Imports

# %%
# %pip install qiskit
# %pip install qiskit-aer

#You may need to restart the runtime for this change to take effect
# %pip install pylatexenc
# %pip install qiskit_ibm_runtime

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit_aer import Aer
from qiskit.primitives import Sampler, StatevectorSampler, Estimator, StatevectorEstimator
import numpy as np

sampler = StatevectorSampler()
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime import SamplerV2 as Sampler
# Out:
# Requirement already satisfied: qiskit in ./.venv/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.11/site-packages (from qiskit) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in ./.venv/lib/python3.11/site-packages (from qiskit) (2.1.1)
# Requirement already satisfied: scipy>=1.5 in ./.venv/lib/python3.11/site-packages (from qiskit) (1.14.1)
# Requirement already satisfied: sympy>=1.3 in ./.venv/lib/python3.11/site-packages (from qiskit) (1.13.2)
# Requirement already satisfied: dill>=0.3 in ./.venv/lib/python3.11/site-packages (from qiskit) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./.venv/lib/python3.11/site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.11/site-packages (from qiskit) (5.3.0)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.11/site-packages (from qiskit) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in ./.venv/lib/python3.11/site-packages (from qiskit) (0.11.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in ./.venv/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.11/site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-aer in ./.venv/lib/python3.11/site-packages (0.15.0)
# Requirement already satisfied: qiskit>=1.1.0 in ./.venv/lib/python3.11/site-packages (from qiskit-aer) (1.2.0)
# Requirement already satisfied: numpy>=1.16.3 in ./.venv/lib/python3.11/site-packages (from qiskit-aer) (2.1.1)
# Requirement already satisfied: scipy>=1.0 in ./.venv/lib/python3.11/site-packages (from qiskit-aer) (1.14.1)
# Requirement already satisfied: psutil>=5 in ./.venv/lib/python3.11/site-packages (from qiskit-aer) (6.0.0)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (1.13.2)
# Requirement already satisfied: dill>=0.3 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.3.0)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.11.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in ./.venv/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.11/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylatexenc in ./.venv/lib/python3.11/site-packages (2.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit_ibm_runtime in ./.venv/lib/python3.11/site-packages (0.29.0)
# Requirement already satisfied: requests>=2.19 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.32.3)
# Requirement already satisfied: requests-ntlm>=1.1.0 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.1.1)
# Requirement already satisfied: urllib3>=1.21.1 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.9.0.post0)
# Requirement already satisfied: websocket-client>=1.5.1 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (0.57.0)
# Requirement already satisfied: pydantic>=2.5.0 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.9.0)
# Requirement already satisfied: qiskit>=1.1.0 in ./.venv/lib/python3.11/site-packages (from qiskit_ibm_runtime) (1.2.0)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.20.6 in ./.venv/lib/python3.11/site-packages (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (3.20.6)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.2 in ./.venv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (2.23.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.venv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (4.12.2)
# Requirement already satisfied: tzdata in ./.venv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.15.1)
# Requirement already satisfied: scipy>=1.5 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (1.14.1)
# Requirement already satisfied: sympy>=1.3 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (1.13.2)
# Requirement already satisfied: dill>=0.3 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (5.3.0)
# Requirement already satisfied: symengine>=0.11 in ./.venv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests>=2.19->qiskit_ibm_runtime) (2024.8.30)
# Requirement already satisfied: cryptography>=1.3 in ./.venv/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (43.0.1)
# Requirement already satisfied: pyspnego>=0.4.0 in ./.venv/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (0.11.1)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.17.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in ./.venv/lib/python3.11/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.20.6->ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (2.9.0)
# Requirement already satisfied: pbr>=2.0.0 in ./.venv/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_ibm_runtime) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.11/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Today's Objectives

# %% [markdown]
# ![oracleantman.png](data:image/png;base64,...)

# %% [markdown]
#  - Implement Grover's Search Algorithm for the case of multiple solutions
#  - Build a quantum circuit for a given CNF Boolean function
#  - Convert a Boolean expression from CNF to ESOP form
#  - Build a quantum circuit for a given ESOP Boolean function

# %% [markdown]
# ## General Boolean Search Problem

# %% [markdown]
# $\text{Let }f:\{0,\dots ,N-1\}\to\{0,1\}\text{ be a Boolean function.}\quad(N=2^{n})$
#
# $f(x)=1\text{ for }x\in\{a_{1},\dots,a_{M}\}\qquad \color{blue}{\text{Notice the multiple solutions!}}$
#
# $f(x)=0 \text{ for all other }x$

# %% [markdown]
# $\text{Any random guess has a success probability of }M/N$
#
# $\text{Can we apply Grover's algorithm?}$

# %% [markdown]
# ### Grover's Search Algorithm for $M$ Solutions

# %% [markdown]
# $1) \text{ Start with an }n\text{-qubit input and 1-qubit output register.}$
# $$|0\dots 0\rangle|0\rangle$$
#
# $2) \text{ Apply a NOT and then Hadamard to the output register.}$
#
# $3) \text{ Apply Hadamards to the input register.}$
#
# $4) \text{ Do the following }R\text{ times, where }\color{red}{R=\big\lfloor\pi\sqrt{N/M}/4\big\rfloor}$
#
# $\quad \text{a) Apply the oracle }\mathbf{U}_{f}$
#
# $\quad \text{b) Apply }\mathbf{W}=-\prod_{i=1}^{n}\mathbf{H}_{i}\mathbf{X}_{i} \;\; \mathbf{C}^{\mathbf{Z}}_{n\dots 2 1}\;\prod_{j=1}^{n}\mathbf{X}_{j}\mathbf{H}_{j}\text{ to the input register}$
#
# $5) \text{ Apply a Hadamard and then NOT gate to the output register.}$
#
# $6) \text{ Measure the input register; the result is most likely } \color{red}{\text{one of } a_{1},\dots,a_{M}}.$

# %% [markdown]
# ### <font color=green>Exercise 1</font>

# %% [markdown]
# $\text{The oracle }\mathbf{U}_{f} = \mathbf{C}_{210}\mathbf{C}_{310}\text{ has }M=2\text{ solutions.}$
#
# $\text{Implement Grover's search algorithm on }\mathbf{U}_{f}.$
#
# $\text{What values of }a\text{ do you find?}$

# %%
n = 4
M = 2
R = math.floor(np.pi * ((2**(n-1)) / M)**0.5 * 0.25)
print(R)

controlList = []
for i in range(2, n):
  controlList.append(i)
print(controlList)

qc=QuantumCircuit(n, n-1)

qc.x(0)
qc.h(0)

for i in range(1, n):
  qc.h(i)

for i in range(R):
  qc.mcx([3, 1], 0)
  qc.mcx([2, 1], 0)
  for i in range(1, n):
    qc.h(i)
    qc.x(i)
  qc.mcp(np.pi, controlList, 1)
  for i in range(1, n):
    qc.x(i)
    qc.h(i)

qc.x(0)
qc.h(0)

for i in range(1, n):
  qc.measure(i, i-1)

qc.draw('mpl')
# Out:
# 1
# [2, 3]

# %%
backend = Aer.get_backend('qasm_simulator')
counts= execute(qc,backend, shots=1024).result().get_counts(qc)
print(counts)
plot_histogram(counts)
# Out:
# {'011': 538, '101': 486}

# %% [markdown]
# The values of a were 110 and 101.

# %% [markdown]
# ## Boolean Satisfiability Problems

# %% [markdown]
# $\text{Any Boolean function can be expressed in Conjunctive Normal Form (CNF)}$
#
# $$\text{e.g. }\qquad f(x_{0},x_{1},x_{2})=\left(x_{0} \texttt{ OR } x_{1} \texttt{ OR }\overline{x_{2}}\right) \texttt{ AND } \left(\overline{x_{0}} \texttt{ OR }x_{2}\right)$$
#
# $ $
#
# $\text{SAT Problem: Does }f(x_{0},\dots x_{n-1})=1 \text{ have a solution?}$
#
# $ $
#
# $\text{Cook-Levin theorem: SAT is NP-complete.}$
#
# $\text{The (classical) Shöning algorithm for SAT runs in time }\left(4/3\right)^{n}\lt\sqrt{2^{n}}$
#
# $\text{When combined with Grover's algorithm, it can be sped up to scale as }\sqrt{\left(4/3\right)^{n}}$

# %% [markdown]
# <font color=blue> Note that in this context the overline means NOT </font>
#
# <font color=blue> i.e. $\overline{x}$ means NOT $x$ </font>
#
# <font color=blue> e.g. if $x=0$ then $\overline{x}=1$ </font>

# %% [markdown]
# ### Reversible Boolean Logic

# %% [markdown]
# $$\text{De Morgan's law }\qquad \overline{\overline{x_{1}}\texttt{ AND }\overline{x_{2}}} = x_{1}\texttt{ OR } x_{2}$$

# %% [markdown]
# ![DeMorgansLaw.png](data:image/png;base64,...)

# %% [markdown]
# ### Building Clauses

# %% [markdown]
# $\text{Example clause:}\quad f(x_{0},x_{1},x_{2})= x_{0} \texttt{ OR } x_{1} \texttt{ OR }\overline{x_{2}} = \left(x_{0} \texttt{ OR }x_{1}\right)\texttt{ OR }\overline{x_{2}}$
#
# $\text{We can store the result of the first logical operation in an }\textbf{auxiliary qubit}\text{ for use in the next logical operation.}$

# %%
oq = QuantumRegister(1,'output')
iq = QuantumRegister(3,'input')
aq = QuantumRegister(2,'auxiliary')

qc = QuantumCircuit(oq,iq,aq)

#First x0 OR x1
qc.x(iq[0])
qc.x(iq[1])
qc.x(aq[0])
qc.ccx(iq[0],iq[1],aq[0])
qc.x(iq[0])
qc.x(iq[1])
qc.barrier()

#Next, the result OR NOT x2
qc.x(aq[0])
qc.x(aq[1])
qc.ccx(iq[2],aq[0],aq[1])
qc.x(aq[0])
qc.barrier()

#Finally, send the result to the output
qc.cx(aq[1],oq)

qc.draw('mpl')

# %% [markdown]
# $f(x_{0},x_{1},x_{2})= x_{0} \texttt{ OR } x_{1} \texttt{ OR }\overline{x_{2}} = \left(x_{0} \texttt{ OR }x_{1}\right)\texttt{ OR }\overline{x_{2}}$

# %% [markdown]
# ### Combining Clauses

# %% [markdown]
# $\text{Example clause:}\quad f(x_{0},x_{1},x_{2})=\left(x_{0} \texttt{ OR } x_{1} \texttt{ OR }\overline{x_{2}}\right) \texttt{ AND } \left(\overline{x_{0}} \texttt{ OR }x_{2}\right)$
#
# $\text{Combine clauses by ANDing their results.}$

# %%
oq = QuantumRegister(1,'output')
iq = QuantumRegister(3,'input')
aq = QuantumRegister(3,'auxiliary')

qc = QuantumCircuit(oq,iq,aq)

#First x0 OR x1
qc.x(iq[0])
qc.x(iq[1])
qc.x(aq[0])
qc.ccx(iq[0],iq[1],aq[0])
qc.x(iq[0])
qc.x(iq[1])
qc.barrier()

#Next, the result OR NOT x2
qc.x(aq[0])
qc.x(aq[1])
qc.ccx(iq[2],aq[0],aq[1])
qc.x(aq[0])
qc.barrier()

#Next, work on the second clause - NOT x0 OR x2
qc.x(iq[2])
qc.x(aq[2])
qc.ccx(iq[0],iq[2],aq[2])
qc.x(iq[2])
qc.barrier()

#Finally, perform the AND and send the result to the output
qc.ccx(aq[2],aq[1],oq)


qc.draw('mpl')

# %% [markdown]
# $f(x_{0},x_{1},x_{2})=\left(x_{0} \texttt{ OR } x_{1} \texttt{ OR }\overline{x_{2}}\right) \texttt{ AND } \left(\overline{x_{0}} \texttt{ OR }x_{2}\right)$

# %% [markdown]
# ### Reusing Qubits

# %% [markdown]
# $f(x_{0},x_{1},x_{2})=\left(x_{0} \texttt{ OR } x_{1} \texttt{ OR }\overline{x_{2}}\right) \texttt{ AND } \left(\overline{x_{0}} \texttt{ OR }x_{2}\right)$
#
# $\text{Because we use reversible logical operations, we can }\textbf{uncompute}\text{ parts of the circuit to restore qubits to their earlier states}$

# %%
oq = QuantumRegister(1,'output')
iq = QuantumRegister(3,'input')
aq = QuantumRegister(2,'auxiliary')

qc = QuantumCircuit(oq,iq,aq)

#First x0 OR x1
qc.x(oq[0])
qc.x(iq[1])
qc.x(iq[0])
qc.ccx(iq[0],iq[1],oq[0])
qc.x(iq[0])
qc.x(iq[1])
qc.barrier()

#Next, the result OR NOT x2
qc.x(oq[0])
qc.x(aq[0])
qc.ccx(oq[0],iq[2],aq[0])
qc.x(oq[0])
qc.barrier()

#Then UNCOMPUTE the first OR, because the result is currently in aq[0]
qc.x(iq[1])
qc.x(iq[0])
qc.ccx(iq[0],iq[1],oq[0])
qc.x(iq[0])
qc.x(iq[1])
qc.x(oq[0])
qc.barrier()


#Next, work on the second clause
qc.x(iq[2])
qc.x(aq[1])
qc.ccx(iq[0],iq[2],aq[1])
qc.x(iq[2])
qc.barrier()

#Finally, perform the AND and send the result to the output
qc.ccx(aq[1],aq[0],oq)

qc.draw('mpl')

# %% [markdown]
# By reusing qubits, we only need a single auxiliary qubit per clause.

# %% [markdown]
# ### <font color=green>Exercise 2</font>

# %% [markdown]
# Build a quantum circuit to implement the following Boolean function
#
# $f(x_{0},x_{1},x_{2})= \left( x_{0}\texttt{ OR }\overline{x_{1}}\right) \texttt{ AND } \left(\overline{x_{0}} \texttt{ OR } x_{1} \texttt{ OR }\overline{x_{2}}\right)$
#
# Try to use a minimal number of auxiliary qubits.

# %% [markdown]
# **You are only building the oracle.**
#
# You need not implement Grover's algorithm for this exercise.

# %%
oq = QuantumRegister(1,'output')
iq = QuantumRegister(3,'input')
aq = QuantumRegister(3,'auxiliary')

qc = QuantumCircuit(oq,iq,aq)

# this set handles the first clause in ()
qc.x(iq[0])
qc.x(aq[0])
qc.ccx(iq[0],iq[1],aq[0])
qc.x(iq[0])
qc.barrier()

# notx0 OR x1
qc.x(iq[1])
qc.x(aq[1])
qc.ccx(iq[0],iq[1],aq[1])
qc.x(iq[1])
qc.barrier()

# aq1 OR notx2
qc.x(aq[1])
qc.x(aq[2])
qc.ccx(aq[1],iq[2],aq[2])
qc.x(aq[1])
qc.barrier()

# first clause all in aq0, second clause all in aq2, combine
qc.ccx(aq[0],aq[2],oq)
qc.barrier

qc.draw('mpl')

# %% [markdown]
# ### Exclusive Sum of Products (ESOP)

# %% [markdown]
# We have been working with our Boolean expressions in Conjunctive Normal Form. CNF Boolean expressions are written as __AND__s of __OR__s.
#
# In ESOP form, we write expressions as __XOR__s of __AND__s.
#
# $$a\texttt{ OR }b=a\texttt{ XOR }b\texttt{ XOR }\left(a\texttt{ AND }b\right)$$
#
# For easier manipulation, we use an alternative notation denoting $\texttt{OR}$ as "+", $\texttt{AND}$ as multiplication, and $\texttt{XOR}$ as "$\oplus$".
# $$a+b = a \oplus b \oplus ab$$

# %% [markdown]
# #### Example:

# %% [markdown]
# $$
# \begin{align}
# \left(x_{1}\texttt{ OR }\overline{x_{2}}\right) \texttt{ AND }x_{3} = & \left(x_{1}+\overline{x_{2}}\right)x_{3} \\
# \\
# = & \left(x_{1}\oplus\overline{x_{2}}\oplus x_{1}\overline{x_{2}}\right)x_{3} \\
# \\
# = & x_{1}x_{3} \oplus \overline{x_{2}}x_{3} \oplus x_{1}\overline{x_{2}}x_{3}
# \end{align}
# $$

# %% [markdown]
# ##### Implementing the quantum circuit for an expression in ESOP form is straightforward. (Unfortunately, converting from CNF to ESOP form is a computationally difficult problem.)

# %% [markdown]
# ![esop.png](data:image/png;base64,...)

# %% [markdown]
# How to implement that CCCX?

# %%
oq = QuantumRegister(1,'output')
iq = QuantumRegister(3,'input')
aq = QuantumRegister(1,'auxiliary')

qc = QuantumCircuit(oq,iq,aq)

#x0 AND x2
qc.ccx(iq[2],iq[0],oq)
qc.barrier()

#NOT x1 AND x2
qc.x(iq[1])
qc.ccx(iq[2],iq[1],oq)
qc.x(iq[1])
qc.barrier()

#Do the CCCX in two steps
#Step1
#NOT x1 AND x2
qc.x(iq[1])
qc.ccx(iq[2],iq[1],aq)
qc.x(iq[1])

#Step2
#Result AND x0
qc.ccx(aq,iq[0],oq)


qc.draw('mpl')

# %% [markdown]
# You can manually break a multi-controlled gate into steps, or you can use pre-built multi-controlled gates (like your recursive Toffoli gates)!

# %%
oq = QuantumRegister(1,'output')
iq = QuantumRegister(3,'input')

qc = QuantumCircuit(oq,iq)

#x0 AND x2
qc.ccx(iq[2],iq[0],oq)
qc.barrier()

#NOT x1 AND x2
qc.x(iq[1])
qc.ccx(iq[2],iq[1],oq)
qc.x(iq[1])
qc.barrier()

#Do the CCCX in one step
#x0 AND NOT x1 AND x2
qc.x(iq[1])
qc.mcx(iq,oq)
qc.x(iq[1])


qc.draw('mpl')

# %%
qc.decompose().draw('mpl')
